# %%
from os.path import join

from elasticsearch import Elasticsearch
import bson
import requests
from tqdm import tqdm

import json
import logging

logger = logging.getLogger(__name__)
logging.basicConfig(level=logging.INFO, format='%(asctime)s %(message)s')  # include timestamp

# %%
class ESClient(object):
    def __init__(self):
        self.es = Elasticsearch(hosts=['166.111.7.106'], port=9200, timeout=60,
                                http_auth=('nekol', 'kegGER123'))
        self.index = 'cs_paper_full'
        self.initialize()

    @staticmethod
    def lower(string):
        if not string:
            return ''
        else:
            return string.lower()

    def initialize(self):
        cur_prop = {'properties': {'title': {'type': 'text'}}}
        try:
            self.es.indices.create("cs_paper_full")
        except:
            pass

        self.es.indices.put_mapping(index='cs_paper_full',doc_type='cs_paper_full', body=cur_prop)
        print("set up mapping...")

    def add_document(self, document: dict, index='cs_paper_full'):
        data = {'title': self.lower(document.get('title')), 'abstract': self.lower(document.get('abstract'))}
        self.es.create(index=index, doc_type=index, id=str(document.get('_id')), body=data)

    def delete_document(self, index, _id):
        result = self.es.delete(index=index, doc_type=index, id=_id)
        if result.get('result') != 'deleted':
            print("deletion failed!")

    def check_id_exists(self, pid: str, index='cs_paper_full'):
        return self.es.exists(index, id=pid)

    def search(self, key_words: str, index='cs_paper_full'):
        dsl = {'query': {'match': {"title": key_words}}}
        result = self.es.search(index=index, doc_type=index, body=dsl)
        return result.get('hits').get('hits')


def each_chunk(stream, separator):
    buffer = ''
    while True:  # until EOF
        chunk = stream.read(4096)  # I propose 4096 or so
        if not chunk:  # EOF?
            yield buffer
            break
        buffer += chunk
        while True:  # until no separator is found
            try:
                part, buffer = buffer.split(separator, 1)

            except ValueError:
                break
            else:
                yield part+'}'


es = ESClient()
# Out:
# 2022-11-23 22:18:55,871 PUT http://166.111.7.106:9200/cs_paper_full [status:400 request:0.005s]
# 2022-11-23 22:18:55,879 PUT http://166.111.7.106:9200/cs_paper_full/_mapping/cs_paper_full [status:200 request:0.008s]
# set up mapping...

# %%
res = es.search(key_words='machine learning')
print(len(res))
source = res[8]['_source']
print(source)
title = source['title']
print(title)
# Out:
# 2022-11-23 22:19:15,088 GET http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.048s]
# 10
# {'title': 'machine learning for hybrid machine translation', 'abstract': 'we describe a substitution-based system for hybrid machine translation (mt that has been extended with machine learning components controlling its phrase selection. the approach is based on a rule-based mt (rbmt system which creates template translations. based on the rule-based generation parse tree and target-to-target alignments, we identify the set of "interesting" translation candidates from one or more translation engines which could be substituted into our translation templates. the substitution process is either controlled by the output from a binary classifier trained on feature vectors from the different mt engines, or it is depending on weights for the decision factors, which have been tuned using mert. we are able to observe improvements in terms of bleu scores over a baseline version of the hybrid system.'}
# machine learning for hybrid machine translation

# %%
hit_number  = 0
hit_rank = 0
hit_all = 0

term2id = {}
i = 0

with open('./computer_science.terms') as f:
    line = f.readline()
    while line:
        res_ = line.split('\t')
        term2id[int(res_[0])] = res_[1].replace('\n','')
        line = f.readline()

concept = {}

with open('./computer_science.taxo') as f:
    line = f.readline()
    while line:
        res_ = line.split('\t')

        parent = term2id[int(res_[0])]
        child = term2id[int(res_[1])]
        if child in concept.keys():
            concept[child].append(parent)
        else:
            concept[child] = [parent]
        line = f.readline()

print("size of concept is {}".format(len(concept)))
all = 0
for key in concept:
    all = all + len(concept[key])

print("size of concept is {}".format(all))

save_json_edge = {}
# Out:
# size of concept is 29483
# size of concept is 46248

# %%
for key in concept:
    parent_list = concept[key]
    res = es.search(key_words=key)
    for parent in parent_list:
        for res_ in res:
            if parent in res_['_source']['title'] or parent in res_['_source']['abstract']:
                hit_number += 1
                hit_all += 1
                if key in save_json_edge:
                    save_json_edge[key + parent].append(res_['_source']['title'])
                else:
                    save_json_edge[key + parent] = [res_['_source']['title']]

print(hit_number)

import json
with open('./Edge.json', 'w') as f:
    json.dump(save_json_edge, f)
# Out:
# 2022-08-01 19:25:39,652 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.005s]
# 2022-08-01 19:25:39,654 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,660 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.005s]
# 2022-08-01 19:25:39,663 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,668 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.005s]
# 2022-08-01 19:25:39,676 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.008s]
# 2022-08-01 19:25:39,679 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:39,682 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,686 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.004s]
# 2022-08-01 19:25:39,688 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,691 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,693 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,696 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:39,700 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:39,702 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,705 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:39,708 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,711 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:39,713 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,715 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.001s]
# 2022-08-01 19:25:39,718 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:39,719 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.001s]
# 2022-08-01 19:25:39,729 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.009s]
# 2022-08-01 19:25:39,731 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,734 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,736 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,739 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,741 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,743 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,746 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,748 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,751 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:39,756 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.005s]
# 2022-08-01 19:25:39,758 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.001s]
# 2022-08-01 19:25:39,764 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.005s]
# 2022-08-01 19:25:39,766 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,769 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:39,772 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:39,775 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:39,778 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:39,782 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:39,784 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:39,788 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:39,790 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,792 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,795 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,798 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:39,802 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,804 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,807 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,809 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,812 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,815 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,817 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,820 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:39,822 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:39,827 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.004s]
# 2022-08-01 19:25:39,830 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:39,833 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:39,856 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.023s]
# 2022-08-01 19:25:39,859 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:39,862 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:39,865 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,869 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.004s]
# 2022-08-01 19:25:39,871 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,873 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,875 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,878 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,880 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,882 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,884 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.001s]
# 2022-08-01 19:25:39,886 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,888 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,890 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,893 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:39,896 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:39,901 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.005s]
# 2022-08-01 19:25:39,904 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:39,906 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,911 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.005s]
# 2022-08-01 19:25:39,913 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,915 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,921 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.005s]
# 2022-08-01 19:25:39,924 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:39,927 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:39,930 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,932 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.001s]
# 2022-08-01 19:25:39,934 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,937 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,939 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,941 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,943 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,946 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,947 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.001s]
# 2022-08-01 19:25:39,950 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,953 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:39,956 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:39,958 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,962 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:39,965 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:39,980 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.015s]
# 2022-08-01 19:25:39,983 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:39,992 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.008s]
# 2022-08-01 19:25:39,994 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:39,997 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,000 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,004 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,007 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,013 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.006s]
# 2022-08-01 19:25:40,018 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.004s]
# 2022-08-01 19:25:40,037 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.019s]
# 2022-08-01 19:25:40,041 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.004s]
# 2022-08-01 19:25:40,044 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,050 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.005s]
# 2022-08-01 19:25:40,054 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,056 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,060 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,062 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,065 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,068 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,070 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,074 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,076 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,079 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,081 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,084 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,087 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,089 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,091 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,093 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,099 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.006s]
# 2022-08-01 19:25:40,103 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,106 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,109 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,112 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,116 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,119 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,123 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,125 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,129 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,149 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.019s]
# 2022-08-01 19:25:40,153 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.004s]
# 2022-08-01 19:25:40,156 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,160 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.004s]
# 2022-08-01 19:25:40,163 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,165 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,168 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,170 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.001s]
# 2022-08-01 19:25:40,174 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,177 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,188 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.011s]
# 2022-08-01 19:25:40,191 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,195 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.004s]
# 2022-08-01 19:25:40,198 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,203 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.005s]
# 2022-08-01 19:25:40,208 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.004s]
# 2022-08-01 19:25:40,212 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.004s]
# 2022-08-01 19:25:40,214 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,216 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,219 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,221 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,224 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,228 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,231 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,235 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,237 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,239 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,242 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,244 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,247 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,249 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,252 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,262 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.010s]
# 2022-08-01 19:25:40,265 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,268 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,272 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.004s]
# 2022-08-01 19:25:40,275 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,295 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.019s]
# 2022-08-01 19:25:40,298 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,302 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,305 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,308 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,312 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.004s]
# 2022-08-01 19:25:40,314 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.001s]
# 2022-08-01 19:25:40,319 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.005s]
# 2022-08-01 19:25:40,322 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,327 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.005s]
# 2022-08-01 19:25:40,330 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,333 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,336 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,339 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,342 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,344 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,347 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,348 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.001s]
# 2022-08-01 19:25:40,351 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,355 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.004s]
# 2022-08-01 19:25:40,358 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,360 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,364 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,368 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,370 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,373 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,391 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.018s]
# 2022-08-01 19:25:40,394 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,398 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,401 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,405 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,409 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.004s]
# 2022-08-01 19:25:40,411 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,415 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,433 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.018s]
# 2022-08-01 19:25:40,436 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,440 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,443 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,453 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.009s]
# 2022-08-01 19:25:40,462 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.008s]
# 2022-08-01 19:25:40,465 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,468 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,474 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.006s]
# 2022-08-01 19:25:40,478 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.004s]
# 2022-08-01 19:25:40,484 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.006s]
# 2022-08-01 19:25:40,487 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,489 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,492 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,495 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,498 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,502 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,524 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.022s]
# 2022-08-01 19:25:40,531 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.006s]
# 2022-08-01 19:25:40,535 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.004s]
# 2022-08-01 19:25:40,537 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,542 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.004s]
# 2022-08-01 19:25:40,550 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.008s]
# 2022-08-01 19:25:40,553 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,557 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,562 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.005s]
# 2022-08-01 19:25:40,567 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.005s]
# 2022-08-01 19:25:40,571 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,576 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.004s]
# 2022-08-01 19:25:40,579 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,582 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,588 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.005s]
# 2022-08-01 19:25:40,591 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,594 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,599 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.004s]
# 2022-08-01 19:25:40,614 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.014s]
# 2022-08-01 19:25:40,616 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,619 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,624 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.005s]
# 2022-08-01 19:25:40,628 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,630 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,632 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,634 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,638 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,641 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,644 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,647 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,656 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.009s]
# 2022-08-01 19:25:40,660 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,662 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,665 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40,668 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,670 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.002s]
# 2022-08-01 19:25:40,673 POST http://166.111.7.106:9200/cs_paper_full/cs_paper_full/_search [status:200 request:0.003s]
# 2022-08-01 19:25:40